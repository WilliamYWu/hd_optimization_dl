# %%
import numpy as np
import decimal
import time 
import jax
import jax.numpy as jnp
from jax import jit, lax
from functools import partial

decimal.getcontext().prec = 10

jax.config.update("jax_enable_x64", True)
jax.config.update('jax_numpy_dtype_promotion', 'standard')

# %%
print(jax.local_device_count())
print(jax.devices())
# Out:
# 1
# [cuda(id=0)]

# %%
# Declare the ranges we work with and then generate all combinations 
r_range = jnp.linspace(start=1.05, stop=1.05, num=1, endpoint=True, dtype=jnp.float64)
beta_range = jnp.linspace(start=0.945, stop=0.945, num=1, endpoint=True, dtype=jnp.float64)
rho_range = jnp.linspace(start=0.9, stop=0.9, num=1, endpoint=True, dtype=jnp.float64)
stdu_range = jnp.linspace(start=0.01, stop=0.01, num=1, endpoint=True, dtype=jnp.float64)
m_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)
gammac_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)

parameter_combos = jnp.array(jnp.meshgrid(r_range, beta_range, rho_range, stdu_range, m_range, gammac_range), dtype=jnp.float64).T.reshape(-1,6)

# %%
nz = 11  # Income grid in terms of z=log(Y)
nb = 200  # Grid points for debt
nz_range = range(0,nz,1)
nb_range = range(0,nb,1)

# %%
def rowenhorst(rho, sigma_eps, n):
    mu_eps = 0
    q = (rho+1) / 2
    nu = ((n-1)/(1-rho**2))**(1/2) * sigma_eps
    z_grid = np.linspace(mu_eps/(1-rho)-nu, mu_eps/(1-rho)+nu, n)
  
    # Looks like we are always using a 2 by 2
    P = np.array(((q, 1-q), (1-q, q)))

    for i in range (1,n-1):
        a1 = np.pad(array=P,pad_width=((0,1),(0,1)),mode='constant',constant_values=0)
        a2 = np.pad(array=P,pad_width=((1,0),(1,0)),mode='constant',constant_values=0)
        a3 = np.pad(array=P,pad_width=((0,1),(1,0)),mode='constant',constant_values=0)
        a4 = np.pad(array=P,pad_width=((1,0),(0,1)),mode='constant',constant_values=0)
        P = q * (a1 + a2) + (1-q) * (a3 + a4)
        P[1:i+1,:] /= 2
    return z_grid, P

@jit
def index_finder(left1, left2, nb, nz):
    left1 = jnp.where(left1 >= nb-2, nb-2, left1)
    left2 = jnp.where(left2 >= nz-2, nz-2, left2)
    return left1, left2

# %%
@jit
def whole_b_dec_new(combo, bgrid, ygrid, ygrid_search, p, x1i, c_dec_use, r, gammac, beta, m):
    z_use = combo[:,:,0]
    b_use = combo[:,:,1]
    left1 = jnp.searchsorted(bgrid, x1i) - 1
    left2 = jnp.searchsorted(ygrid, ygrid_search)
    left1, left2 = index_finder(left1, left2, nb, nz)

    left_values = jnp.concatenate((bgrid[left1], ygrid[lesft2]))
    right_values = jnp.concatenate((bgrid[left1+1], ygrid[left2+1]))
    
    xi = jnp.concatenate((x1i, ygrid_search))
    w1 = (right_values - xi) / (right_values - left_values)
    w2 = 1 - w1

    w11 = jnp.concatenate((w1[0:nz,:,:], w2[0:nz,:,:], w1[0:nz,:,:], w2[0:nz,:,:]))
    w22 = jnp.concatenate((w1[nz:len(w1),:,:], w1[nz:len(w1),:,:], w2[nz:len(w2),:,:], w2[nz:len(w2),:,:]))
    p_x = jnp.concatenate((left2, left2, left2+1, left2+1))
    p_y = jnp.concatenate((left1, left1+1, left1, left1+1))

    w_new = w11 * w22 * c_dec_use[p_x, p_y]
    w_new = w_new.reshape(4,11,nz,nb)
    int_ct_prime = jnp.sum(w_new, axis=0)
    int_ct_prime= jnp.maximum(int_ct_prime, 1e-20) ** (-gammac)

    sol_ct2 = jnp.sum(p * int_ct_prime, axis=0)
    c_dec_new = (beta * r * sol_ct2) ** (-1 / gammac)
    b_dec_new = c_dec_new - z_use + r * b_use

    check_array = m * z_use
    b_dec_new = jnp.where(b_dec_new > check_array, check_array, b_dec_new)
    return b_dec_new

# %%
r,beta,rho,stdu,m,gammac = np.ravel(parameter_combos[0])

# Rowenhorst Discretization
log_y, p = rowenhorst(rho=rho, sigma_eps=stdu, n=nz)

ygrid = jnp.exp(log_y)

# Borrowing Grid
b_min = 0.75 * m
b_max = m * ygrid[-1]
bgrid = jnp.linspace(b_min, b_max, nb)

# Initial guess
z_m, b_m = jnp.meshgrid(ygrid,bgrid)
z_m, b_m = z_m.T, b_m.T
c_dec_old = jnp.maximum(1e-100, -r * b_m + (1 + m) * z_m)
b_dec_use = c_dec_old + r * b_m - z_m

combo = jnp.array(np.meshgrid(ygrid.T, bgrid), dtype=jnp.float64).T.reshape(-1,2).reshape(nz,nb,2)
ygrid_search = jnp.tile(ygrid[:, jnp.newaxis, jnp.newaxis], (1, nz, nb))
p = jnp.repeat(p.T[:, :, np.newaxis], 200, axis=2)

# %%
r,beta,rho,stdu,m,gammac = np.ravel(parameter_combos[0])

# Rowenhorst Discretizations
log_y, p = rowenhorst(rho=rho, sigma_eps=stdu, n=nz)

ygrid = jnp.exp(log_y)

# Borrowing Grid
b_min = 0.75 * m
b_max = m * ygrid[-1]
bgrid = jnp.linspace(b_min, b_max, nb)

# Initial guess
z_m, b_m = jnp.meshgrid(ygrid,bgrid)
z_m, b_m = z_m.T, b_m.T
c_dec_old = jnp.maximum(1e-100, -r * b_m + (1 + m) * z_m)
b_dec_use = c_dec_old + r * b_m - z_m

combo = jnp.array(np.meshgrid(ygrid.T, bgrid), dtype=jnp.float64).T.reshape(-1,2).reshape(nz,nb,2)
ygrid_search = jnp.tile(ygrid[:, jnp.newaxis, jnp.newaxis], (1, nz, nb))
p = jnp.repeat(p.T[:, :, np.newaxis], 200, axis=2)

count = 0
dist = 100
nz,nb = b_dec_use.shape

while dist > 1e-10: 
    count += 1
    c_dec_use = b_dec_use - r * b_m + z_m
    x1i = jnp.repeat(b_dec_use.T,11,axis=1).T.reshape(nz,nz,nb)
    int_ct_prime = jnp.empty((1, nz), dtype=np.float64)
    c_dec_new = jnp.empty((nz, nb), dtype=np.float64)
    b_dec_new = jnp.empty((nz, nb), dtype=np.float64)
    w1 = jnp.empty((1,nz), dtype=np.float64)
    w2 = jnp.empty((1,nz), dtype=np.float64)
    pf = jnp.empty(nz*4, dtype=np.float64)
    b_dec_new = whole_b_dec_new(
          combo=combo, 
          bgrid=bgrid,
          ygrid=ygrid,
          ygrid_search=ygrid_search,
          p=p,
          x1i=x1i, 
          c_dec_use=c_dec_use, 
          r=r, 
          gammac=gammac, 
          beta=beta, 
          m=m
          )

    b_dec_new2 = b_dec_new * 0.25 + b_dec_use * (1 - 0.25)
    dist = jnp.linalg.norm(jnp.abs(b_dec_new - b_dec_use))
    if count % 10 == 0:
            print(count,dist)
    b_dec_use = b_dec_new2
# Out:
# 10 0.39962113611784894
# 20 0.09394111577395027
# 30 0.028745504444909874
# 40 0.009043923334968168
# 50 0.0027132359301465995
# 60 0.0007616789587084746
# 70 0.00020115971331456366
# 80 5.066423865064994e-05
# 90 1.2340705624134153e-05
# 100 2.9401962456972064e-06
# 110 6.908900005908191e-07
# 120 1.6113230033175678e-07
# 130 3.7521183796931396e-08
# 140 8.78489392614833e-09
# 150 2.08670804392508e-09
# 160 5.08258317856482e-10
# 170 1.2824925730304646e-10

# %% [markdown]
# ## Working Version - Not Function

# %%
from memory_jax import memory_function
# %load_ext memory_profiler

# %%
# %mprun -f memory_function memory_function()
# Out:
# 10 0.39962113611784894
# 20 0.09394111577395027
# 30 0.028745504444909874
# 40 0.009043923334968168
# 50 0.0027132359301465995
# 60 0.0007616789587084746
# 70 0.00020115971331456366
# 80 5.066423865064994e-05
# 90 1.2340705624134153e-05
# 100 2.9401962456972064e-06
# 110 6.908900005908191e-07
# 120 1.6113230033175678e-07
# 130 3.7521183796931396e-08
# 140 8.78489392614833e-09
# 150 2.08670804392508e-09
# 160 5.08258317856482e-10
# 170 1.2824925730304646e-10
# Filename: /home/code/FiPit/memory_jax.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     14    168.7 MiB    168.7 MiB           1   def memory_function():
#     15                                                 # Declare the ranges we work with and then generate all combinations
#     16    658.8 MiB    490.0 MiB           1           r_range = jnp.linspace(start=1.05, stop=1.05, num=1, endpoint=True, dtype=jnp.float64)
#     17    658.8 MiB      0.0 MiB           1           beta_range = jnp.linspace(start=0.945, stop=0.945, num=1, endpoint=True, dtype=jnp.float64)
#     18    658.8 MiB      0.0 MiB           1           rho_range = jnp.linspace(start=0.9, stop=0.9, num=1, endpoint=True, dtype=jnp.float64)
#     19    658.8 MiB      0.0 MiB           1           stdu_range = jnp.linspace(start=0.01, stop=0.01, num=1, endpoint=True, dtype=jnp.float64)
#     20    658.8 MiB      0.0 MiB           1           m_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)
#     21    658.8 MiB      0.0 MiB           1           gammac_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)
#     22
#     23    672.1 MiB     13.4 MiB           1           parameter_combos = jnp.array(jnp.meshgrid(r_range, beta_range, rho_range, stdu_range, m_range, gammac_range), dtype=jnp.float64).T.reshape(-1,6)
#     24    801.3 MiB    129.2 MiB           1           r,beta,rho,stdu,m,gammac = np.ravel(parameter_combos[0])
#     25
#     26    801.3 MiB      0.0 MiB           1           nz = 11  # Income grid in terms of z=log(Y)
#     27    801.3 MiB      0.0 MiB           1           nb = 200  # Grid points for debt
#     28    801.3 MiB      0.0 MiB           1           nz_range = range(0,nz,1)
#     29    801.3 MiB      0.0 MiB           1           nb_range = range(0,nb,1)
#     30
#     31                                                 # Rowenhorst Discretization
#     32    801.3 MiB      0.0 MiB           1           mu_eps = 0
#     33    801.3 MiB      0.0 MiB           1           q = (rho+1) / 2
#     34    801.3 MiB      0.0 MiB           1           nu = ((nz-1)/(1-rho**2))**(1/2) * stdu
#     35    801.3 MiB      0.0 MiB           1           log_y = np.linspace(mu_eps/(1-rho)-nu, mu_eps/(1-rho)+nu, nz)
#     36
#     37                                                 # Looks like we are always using a 2 by 2
#     38    801.3 MiB      0.0 MiB           1           p = np.array(((q, 1-q), (1-q, q)))
#     39
#     40    801.8 MiB      0.0 MiB          10           for i in range (1,nz-1):
#     41    801.8 MiB      0.4 MiB           9               a1 = np.pad(array=p,pad_width=((0,1),(0,1)),mode='constant',constant_values=0)
#     42    801.8 MiB      0.0 MiB           9               a2 = np.pad(array=p,pad_width=((1,0),(1,0)),mode='constant',constant_values=0)
#     43    801.8 MiB      0.0 MiB           9               a3 = np.pad(array=p,pad_width=((0,1),(1,0)),mode='constant',constant_values=0)
#     44    801.8 MiB      0.0 MiB           9               a4 = np.pad(array=p,pad_width=((1,0),(0,1)),mode='constant',constant_values=0)
#     45    801.8 MiB      0.0 MiB           9               p = q * (a1 + a2) + (1-q) * (a3 + a4)
#     46    801.8 MiB      0.0 MiB           9               p[1:i+1,:] /= 2
#     47    804.7 MiB      2.9 MiB           1           ygrid = jnp.exp(log_y)
#     48
#     49                                                 # Borrowing Grid
#     50    804.7 MiB      0.0 MiB           1           b_min = 0.75 * m
#     51    807.4 MiB      2.7 MiB           1           b_max = m * ygrid[-1]
#     52    809.4 MiB      2.0 MiB           1           bgrid = jnp.linspace(b_min, b_max, nb)
#     53
#     54                                                 # Initial guess
#     55    810.9 MiB      1.4 MiB           1           z_m, b_m = jnp.meshgrid(ygrid,bgrid)
#     56    811.6 MiB      0.8 MiB           1           z_m, b_m = z_m.T, b_m.T
#     57    813.6 MiB      1.9 MiB           1           c_dec_old = jnp.maximum(1e-100, -r * b_m + (1 + m) * z_m)
#     58    814.2 MiB      0.6 MiB           1           b_dec_use = c_dec_old + r * b_m - z_m
#     59
#     60    815.9 MiB      1.7 MiB           1           combo = jnp.array(np.meshgrid(ygrid.T, bgrid), dtype=jnp.float64).T.reshape(-1,2).reshape(nz,nb,2)
#     61    819.0 MiB      3.1 MiB           1           ygrid_search = jnp.tile(ygrid[:, jnp.newaxis, jnp.newaxis], (1, nz, nb))
#     62    822.7 MiB      3.7 MiB           1           p = jnp.repeat(p.T[:, :, np.newaxis], 200, axis=2)
#     63
#     64    822.7 MiB      0.0 MiB           1           count = 0
#     65    822.7 MiB      0.0 MiB           1           dist = 100
#     66    822.7 MiB      0.0 MiB           1           nz,nb = b_dec_use.shape
#     67
#     68    868.1 MiB      0.1 MiB         173           while dist > 1e-10:
#     69    868.1 MiB      0.0 MiB         172                   count += 1
#     70    868.1 MiB      0.0 MiB         172                   c_dec_use = b_dec_use - r * b_m + z_m
#     71
#     72    868.1 MiB      6.2 MiB         172                   x1i = jnp.repeat(b_dec_use.T,11,axis=1).T.reshape(nz,nz,nb)
#     73    868.1 MiB      1.6 MiB         172                   int_ct_prime = jnp.empty((1, nz), dtype=np.float64)
#     74    868.1 MiB      0.7 MiB         172                   c_dec_new = b_dec_new = jnp.empty((nz, nb), dtype=np.float64)
#     75    868.1 MiB      0.0 MiB         172                   w1 = w2 = jnp.empty((1,nz), dtype=np.float64)
#     76    868.1 MiB      0.6 MiB         172                   pf = jnp.empty(nz*4, dtype=np.float64)
#     77
#     78    868.1 MiB      1.2 MiB         172                   z_use = combo[:,:,0]
#     79    868.1 MiB      0.0 MiB         172                   b_use = combo[:,:,1]
#     80    868.1 MiB      5.4 MiB         172                   left1 = jnp.searchsorted(bgrid, x1i) - 1
#     81    868.1 MiB      2.3 MiB         172                   left2 = jnp.searchsorted(ygrid, ygrid_search)
#     82    868.1 MiB      0.4 MiB         172                   left1 = jnp.where(left1 >= nb-2, nb-2, left1)
#     83    868.1 MiB      0.0 MiB         172                   left2 = jnp.where(left2 >= nz-2, nz-2, left2)
#     84
#     85    868.1 MiB      5.6 MiB         172                   left_values = jnp.concatenate((bgrid[left1], ygrid[left2]))
#     86    868.1 MiB      0.6 MiB         172                   right_values = jnp.concatenate((bgrid[left1+1], ygrid[left2+1]))
#     87
#     88    868.1 MiB      1.2 MiB         172                   left_values2 = jnp.stack((bgrid[left1], ygrid[left2]), axis=0).reshape(nz*2,nz,nb)
#     89    868.1 MiB      0.0 MiB         172                   right_values2 = jnp.stack((bgrid[left1+1], ygrid[left2+1]), axis=0).reshape(nz*2,nz,nb)
#     90
#     91    868.1 MiB      0.0 MiB         172                   xi = jnp.concatenate((x1i, ygrid_search))
#     92    868.1 MiB      1.8 MiB         172                   w1 = (right_values - xi) / (right_values - left_values)
#     93    868.1 MiB      0.7 MiB         172                   w2 = 1 - w1
#     94
#     95    868.1 MiB      1.4 MiB         172                   w11 = jnp.concatenate((w1[0:nz,:,:], w2[0:nz,:,:], w1[0:nz,:,:], w2[0:nz,:,:]))
#     96    868.1 MiB      0.0 MiB         172                   w22 = jnp.concatenate((w1[nz:len(w1),:,:], w1[nz:len(w1),:,:], w2[nz:len(w2),:,:], w2[nz:len(w2),:,:]))
#     97    868.1 MiB      0.7 MiB         172                   p_x = jnp.concatenate((left2, left2, left2+1, left2+1))
#     98    868.1 MiB      0.0 MiB         172                   p_y = jnp.concatenate((left1, left1+1, left1, left1+1))
#     99    868.1 MiB      5.8 MiB         172                   w_new = w11 * w22 * c_dec_use[p_x, p_y]
#    100    868.1 MiB      0.5 MiB         172                   w_new = w_new.reshape(4,11,nz,nb)
#    101    868.1 MiB      1.6 MiB         172                   int_ct_prime = jnp.sum(w_new, axis=0)
#    102    868.1 MiB      1.7 MiB         172                   int_ct_prime= jnp.maximum(int_ct_prime, 1e-20) ** (-gammac)
#    103
#    104    868.1 MiB      1.0 MiB         172                   sol_ct2 = jnp.sum(p * int_ct_prime, axis=0)
#    105    868.1 MiB      1.0 MiB         172                   c_dec_new = (beta * r * sol_ct2) ** (-1 / gammac)
#    106    868.1 MiB      0.0 MiB         172                   b_dec_new = c_dec_new - z_use + r * b_use
#    107
#    108    868.1 MiB      0.0 MiB         172                   check_array = m * z_use
#    109    868.1 MiB      0.9 MiB         172                   b_dec_new = jnp.where(b_dec_new > check_array, check_array, b_dec_new)
#    110    868.1 MiB      0.6 MiB         172                   b_dec_new2 = b_dec_new * 0.25 + b_dec_use * (1 - 0.25)
#    111    868.1 MiB      1.9 MiB         172                   dist = jnp.linalg.norm(jnp.abs(b_dec_new - b_dec_use))
#    112    868.1 MiB      0.0 MiB         172                   if count % 10 == 0:
#    113    868.1 MiB      0.0 MiB          17                           print(count,dist)
#    114    868.1 MiB      0.0 MiB         172                   b_dec_use = b_dec_new2

# %% [markdown]
# # Debug Here

# %%
import numpy as np
import decimal
import time 
import jax
import jax.numpy as jnp
from jax import jit, lax
from functools import partial

decimal.getcontext().prec = 10

jax.config.update("jax_enable_x64", True)
jax.config.update('jax_numpy_dtype_promotion', 'standard')

# Declare the ranges we work with and then generate all combinations 
r_range = jnp.linspace(start=1.05, stop=1.05, num=1, endpoint=True, dtype=jnp.float64)
beta_range = jnp.linspace(start=0.945, stop=0.945, num=1, endpoint=True, dtype=jnp.float64)
rho_range = jnp.linspace(start=0.9, stop=0.9, num=1, endpoint=True, dtype=jnp.float64)
stdu_range = jnp.linspace(start=0.01, stop=0.01, num=1, endpoint=True, dtype=jnp.float64)
m_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)
gammac_range = jnp.linspace(start=1., stop=1., num=1, endpoint=True, dtype=jnp.float64)

parameter_combos = jnp.array(jnp.meshgrid(r_range, beta_range, rho_range, stdu_range, m_range, gammac_range), dtype=jnp.float64).T.reshape(-1,6)
r,beta,rho,stdu,m,gammac = np.ravel(parameter_combos[0])

nz = 11  # Income grid in terms of z=log(Y)
nb = 200  # Grid points for debt
nz_range = range(0,nz,1)
nb_range = range(0,nb,1)

# Rowenhorst Discretization
mu_eps = 0
q = (rho+1) / 2
nu = ((nz-1)/(1-rho**2))**(1/2) * stdu
log_y = np.linspace(mu_eps/(1-rho)-nu, mu_eps/(1-rho)+nu, nz)

# Looks like we are always using a 2 by 2
p = np.array(((q, 1-q), (1-q, q)))

for i in range (1,nz-1):
    a1 = np.pad(array=p,pad_width=((0,1),(0,1)),mode='constant',constant_values=0)
    a2 = np.pad(array=p,pad_width=((1,0),(1,0)),mode='constant',constant_values=0)
    a3 = np.pad(array=p,pad_width=((0,1),(1,0)),mode='constant',constant_values=0)
    a4 = np.pad(array=p,pad_width=((1,0),(0,1)),mode='constant',constant_values=0)
    p = q * (a1 + a2) + (1-q) * (a3 + a4)
    p[1:i+1,:] /= 2
ygrid = jnp.exp(log_y)

# Borrowing Grid
b_min = 0.75 * m
b_max = m * ygrid[-1]
bgrid = jnp.linspace(b_min, b_max, nb)

# Initial guess
z_m, b_m = jnp.meshgrid(ygrid,bgrid)
z_m, b_m = z_m.T, b_m.T
c_dec_old = jnp.maximum(1e-100, -r * b_m + (1 + m) * z_m)
b_dec_use = c_dec_old + r * b_m - z_m

combo = jnp.array(np.meshgrid(ygrid.T, bgrid), dtype=jnp.float64).T.reshape(-1,2).reshape(nz,nb,2)
ygrid_search = jnp.tile(ygrid[:, jnp.newaxis, jnp.newaxis], (1, nz, nb))
p = jnp.repeat(p.T[:, :, np.newaxis], 200, axis=2)

count = 0
dist = 100
nz,nb = b_dec_use.shape

while dist > 1e-10: 
        count += 1
        c_dec_use = b_dec_use - r * b_m + z_m

        x1i = jnp.repeat(b_dec_use.T,11,axis=1).T.reshape(nz,nz,nb)
        int_ct_prime = jnp.empty((1, nz), dtype=np.float64)
        c_dec_new = b_dec_new = jnp.empty((nz, nb), dtype=np.float64)
        w1 = w2 = jnp.empty((1,nz), dtype=np.float64)
        pf = jnp.empty(nz*4, dtype=np.float64)

        z_use = combo[:,:,0]
        b_use = combo[:,:,1]
        left1 = jnp.searchsorted(bgrid, x1i) - 1
        left2 = jnp.searchsorted(ygrid, ygrid_search)
        left1 = jnp.where(left1 >= nb-2, nb-2, left1)
        left2 = jnp.where(left2 >= nz-2, nz-2, left2)

        left_values = jnp.concatenate((bgrid[left1], ygrid[left2]))
        right_values = jnp.concatenate((bgrid[left1+1], ygrid[left2+1]))

        left_values2 = jnp.stack((bgrid[left1], ygrid[left2]), axis=0).reshape(nz*2,nz,nb)
        right_values2 = jnp.stack((bgrid[left1+1], ygrid[left2+1]), axis=0).reshape(nz*2,nz,nb)

        xi = jnp.concatenate((x1i, ygrid_search))
        w1 = (right_values - xi) / (right_values - left_values)
        w2 = 1 - w1

        w11 = jnp.concatenate((w1[0:nz,:,:], w2[0:nz,:,:], w1[0:nz,:,:], w2[0:nz,:,:]))
        w22 = jnp.concatenate((w1[nz:len(w1),:,:], w1[nz:len(w1),:,:], w2[nz:len(w2),:,:], w2[nz:len(w2),:,:]))
        p_x = jnp.concatenate((left2, left2, left2+1, left2+1))
        p_y = jnp.concatenate((left1, left1+1, left1, left1+1))
        w_new = w11 * w22 * c_dec_use[p_x, p_y]
        w_new = w_new.reshape(4,11,nz,nb)
        int_ct_prime = jnp.sum(w_new, axis=0)
        int_ct_prime= jnp.maximum(int_ct_prime, 1e-20) ** (-gammac)

        sol_ct2 = jnp.sum(p * int_ct_prime, axis=0)
        c_dec_new = (beta * r * sol_ct2) ** (-1 / gammac)
        b_dec_new = c_dec_new - z_use + r * b_use

        check_array = m * z_use
        b_dec_new = jnp.where(b_dec_new > check_array, check_array, b_dec_new)
        b_dec_new2 = b_dec_new * 0.25 + b_dec_use * (1 - 0.25)
        dist = jnp.linalg.norm(jnp.abs(b_dec_new - b_dec_use))
        if count % 10 == 0:
                print(count,dist)
        b_dec_use = b_dec_new2
